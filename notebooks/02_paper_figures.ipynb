# %% [markdown]
# # 02 — Paper figures
#
# The existing sample-selection and annotation-display logic is now in `scripts/generate_paper_figures.py`. This notebook was not executed during cleanup. Existing figures remain unchanged in `paper_figures/`. It does not run a model or calculate performance metrics.

# %% [markdown]
# ## Paths and display settings
#
# Run from the repository root or `notebooks/`. Outputs go to a separate directory to preserve the supplied figures.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / 'detection_dataset').is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'scripts'))
from generate_paper_figures import generate_figures

DATASET = ROOT / 'detection_dataset'
OUTPUT = ROOT / 'outputs/paper_figures'
SPLIT = 'train'
SEED = 42  # Figure selection seed; not the verified final training seed.

# %% [markdown]
# ## Ground-truth annotation figures
#
# Manual sample filenames match the original notebook and may resolve to another split. The figure script labels the actual source split. These are annotation illustrations, not predictions.

# %%
generate_figures(DATASET, OUTPUT, split=SPLIT, samples=3, seed=SEED, dpi=300)
