# %%
import os
from collections import Counter

IMAGE_DIR = "../detection_dataset/images/train"
LABEL_DIR = "../detection_dataset/labels/train"

IMAGE_EXTENSIONS = (".jpg", ".jpeg", ".png")

missing_labels = []
missing_images = []
empty_labels = []
invalid_labels = []

class_counter = Counter()

total_images = 0
total_annotations = 0

# %%
image_files = [
    f for f in os.listdir(IMAGE_DIR)
    if f.lower().endswith(IMAGE_EXTENSIONS)
]

label_files = [
    f for f in os.listdir(LABEL_DIR)
    if f.endswith(".txt")
]

print(f"Total Image Files: {len(image_files)}")
print(f"Total Label Files: {len(label_files)}")
# Out:
# Total Image Files: 1698
# Total Label Files: 623

# %%
for image_file in image_files:

    total_images += 1

    image_name = os.path.splitext(image_file)[0]
    label_file = image_name + ".txt"

    label_path = os.path.join(LABEL_DIR, label_file)

    if not os.path.exists(label_path):
        missing_labels.append(image_file)
        continue

    if os.path.getsize(label_path) == 0:
        empty_labels.append(label_file)
        continue

    with open(label_path, "r") as f:
        lines = f.readlines()

    for line in lines:

        parts = line.strip().split()

        if len(parts) != 5:
            invalid_labels.append(label_file)
            continue

        class_id = parts[0]

        class_counter[class_id] += 1
        total_annotations += 1

# %%
print("\n========== DATASET REPORT ==========")

print(f"\nTotal Images: {total_images}")
print(f"Total Annotations: {total_annotations}")

print("\nClass Distribution:")
print(f"Healthy (0): {class_counter['0']}")
print(f"Unhealthy (1): {class_counter['1']}")

print("\nMissing Labels:", len(missing_labels))
print("Empty Labels:", len(empty_labels))
print("Invalid Labels:", len(invalid_labels))
print("Missing Images:", len(missing_images))
# Out:
# ========== DATASET REPORT ==========
#
# Total Images: 943
# Total Annotations: 1230
#
# Class Distribution:
# Healthy (0): 679
# Unhealthy (1): 551
#
# Missing Labels: 321
# Empty Labels: 0
# Invalid Labels: 0
# Missing Images: 0

# %%
print("========== MISSING LABEL FILES ==========\n")

for item in missing_labels:
    print(item)
# Out:
# ========== MISSING LABEL FILES ==========
#
# unhealthy_0943.jpg
# healthy_0465.jpg
# unhealthy_0544.jpg
# healthy_0845.jpg
# healthy_0579.jpg
# healthy_1344.jpg
# healthy_0521.jpg
# unhealthy_0492.jpg
# unhealthy_1018.jpg
# unhealthy_0678.jpg
# healthy_0952.jpg
# healthy_0677.jpg
# healthy_1369.jpg
# unhealthy_0664.jpg
# healthy_0459.jpg
# healthy_0863.jpg
# healthy_0549.jpg
# unhealthy_0969.jpg
# unhealthy_0852.jpg
# unhealthy_0452.jpg
# healthy_1035.jpg
# unhealthy_0900.jpg
# unhealthy_0515.jpg
# healthy_1013.jpg
# unhealthy_0839.jpg
# unhealthy_0599.jpg
# unhealthy_0461.jpg
# healthy_1089.jpg
# unhealthy_0673.jpg
# unhealthy_0931.jpg
# unhealthy_0543.jpg
# unhealthy_0923.jpg
# healthy_0565.jpg
# healthy_0682.jpg
# unhealthy_0892.jpg
# unhealthy_0859.jpg
# healthy_1163.jpg
# unhealthy_0699.jpg
# unhealthy_0797.jpg
# unhealthy_0547.jpg
# unhealthy_0751.jpg
# healthy_0648.jpg
# healthy_0452.jpg
# healthy_0794.jpg
# unhealthy_0577.jpg
# healthy_0885.jpg
# healthy_1129.jpg
# healthy_1292.jpg
# unhealthy_0676.jpg
# unhealthy_0737.jpg
# unhealthy_0520.jpg
# healthy_0924.jpg
# healthy_1213.jpg
# healthy_1357.jpg
# healthy_0570.jpg
# healthy_0687.jpg
# unhealthy_0728.jpg
# healthy_0899.jpg
# unhealthy_0785.jpg
# healthy_0659.jpg
# healthy_0634.jpg
# healthy_0882.jpg
# healthy_0658.jpg
# healthy_1181.jpg
# healthy_0512.jpg
# healthy_1225.jpg
# healthy_1027.jpg
# healthy_1145.jpg
# healthy_1158.jpg
# healthy_1175.jpg
# unhealthy_0809.jpg
# unhealthy_0763.jpg
# healthy_0915.jpg
# unhealthy_0718.jpg
# healthy_1073.jpg
# unhealthy_0871.jpg
# healthy_0524.jpg
# healthy_0567.jpg
# healthy_0758.jpg
# healthy_0497.jpg
# unhealthy_0822.jpg
# unhealthy_0572.jpg
# healthy_0801.jpg
# healthy_0759.jpg
# unhealthy_0842.jpg
# unhealthy_1011.jpg
# unhealthy_0628.jpg
# healthy_1391.jpg
# healthy_0761.jpg
# unhealthy_0973.jpg
# healthy_1066.jpg
# unhealthy_0592.jpg
# healthy_0999.jpg
# unhealthy_0558.jpg
# unhealthy_0844.jpg
# healthy_0735.jpg
# healthy_0752.jpg
# unhealthy_1021.jpg
# healthy_1137.jpg
# unhealthy_0792.jpg
# unhealthy_1017.jpg
# unhealthy_0494.jpg
# unhealthy_0535.jpg
# healthy_0744.jpg
# healthy_1050.jpg
# healthy_0520.jpg
# healthy_0514.jpg
# healthy_0527.jpg
# unhealthy_0614.jpg
# unhealthy_0525.jpg
# healthy_0754.jpg
# healthy_0998.jpg
# healthy_0732.jpg
# unhealthy_0821.jpg
# healthy_0619.jpg
# healthy_0809.jpg
# healthy_1166.jpg
# healthy_0945.jpg
# healthy_0525.jpg
# healthy_0694.jpg

# %% [markdown]
# Resized image image number

# %%
import os

healthy_path = "../resized_images/healthy01"
unhealthy_path = "../resized_images/unhealthy01"

healthy_count = len([
    f for f in os.listdir(healthy_path)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
])

unhealthy_count = len([
    f for f in os.listdir(unhealthy_path)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
])

total_images = healthy_count + unhealthy_count

print("========== RESIZED IMAGE REPORT ==========\n")

print(f"Healthy Images   : {healthy_count}")
print(f"Unhealthy Images : {unhealthy_count}")
print(f"Total Images     : {total_images}")
# Out:
# ========== RESIZED IMAGE REPORT ==========
#
# Healthy Images   : 305
# Unhealthy Images : 90
# Total Images     : 395

# %%
# Detection dataset images number

# %%
import os

IMAGE_EXTENSIONS = (".jpg", ".jpeg", ".png")

# Paths
train_path = "../detection_dataset/images/train"
val_path = "../detection_dataset/images/val"
test_path = "../detection_dataset/images/test"

# Count function
def count_images(folder):

    return len([
        f for f in os.listdir(folder)
        if f.lower().endswith(IMAGE_EXTENSIONS)
    ])

# Counts
train_count = count_images(train_path)
val_count = count_images(val_path)
test_count = count_images(test_path)

total_count = train_count + val_count + test_count

# Report
print("========== DETECTION DATASET REPORT ==========\n")

print(f"Train Images : {train_count}")
print(f"Val Images   : {val_count}")
print(f"Test Images  : {test_count}")

print("\n-----------------------------")

print(f"Total Images : {total_count}")
# Out:
# ========== DETECTION DATASET REPORT ==========
#
# Train Images : 1698
# Val Images   : 486
# Test Images  : 248
#
# -----------------------------
# Total Images : 2432

# %%
import os
from collections import Counter

# =====================================
# DATASET PATHS
# =====================================

IMAGE_DIRS = [
    "../detection_dataset/images/train",
    "../detection_dataset/images/val",
    "../detection_dataset/images/test"
]

LABEL_DIRS = [
    "../detection_dataset/labels/train",
    "../detection_dataset/labels/val",
    "../detection_dataset/labels/test"
]

IMAGE_EXTENSIONS = (".jpg", ".jpeg", ".png")

# =====================================
# COUNTERS
# =====================================

missing_labels = []
missing_images = []
empty_labels = []
invalid_labels = []

class_counter = Counter()

total_images = 0
total_annotations = 0

# =====================================
# CHECK ALL SPLITS
# =====================================

for IMAGE_DIR, LABEL_DIR in zip(IMAGE_DIRS, LABEL_DIRS):

    image_files = [
        f for f in os.listdir(IMAGE_DIR)
        if f.lower().endswith(IMAGE_EXTENSIONS)
    ]

    label_files = [
        f for f in os.listdir(LABEL_DIR)
        if f.endswith(".txt")
    ]

    # -----------------------------
    # IMAGE -> LABEL
    # -----------------------------

    for image_file in image_files:

        total_images += 1

        image_name = os.path.splitext(image_file)[0]
        label_file = image_name + ".txt"

        label_path = os.path.join(LABEL_DIR, label_file)

        # Missing label
        if not os.path.exists(label_path):
            missing_labels.append(image_file)
            continue

        # Empty label
        if os.path.getsize(label_path) == 0:
            empty_labels.append(label_file)
            continue

        # Read labels
        with open(label_path, "r") as f:
            lines = f.readlines()

        for line in lines:

            parts = line.strip().split()

            # YOLO format check
            if len(parts) != 5:
                invalid_labels.append(label_file)
                continue

            class_id = parts[0]

            class_counter[class_id] += 1
            total_annotations += 1

    # -----------------------------
    # LABEL -> IMAGE
    # -----------------------------

    for label_file in label_files:

        label_name = os.path.splitext(label_file)[0]

        image_found = False

        for ext in IMAGE_EXTENSIONS:

            image_path = os.path.join(
                IMAGE_DIR,
                label_name + ext
            )

            if os.path.exists(image_path):
                image_found = True
                break

        if not image_found:
            missing_images.append(label_file)

# =====================================
# FINAL REPORT
# =====================================

print("\n========== FULL DATASET REPORT ==========")

print(f"\nTotal Images: {total_images}")
print(f"Total Annotations: {total_annotations}")

print("\nClass Distribution:")
print(f"Healthy (0): {class_counter['0']}")
print(f"Unhealthy (1): {class_counter['1']}")

print("\nMissing Labels:", len(missing_labels))
print("Empty Labels:", len(empty_labels))
print("Invalid Labels:", len(invalid_labels))
print("Missing Images:", len(missing_images))

# =====================================
# OPTIONAL DETAILS
# =====================================

if missing_labels:

    print("\n========== MISSING LABEL FILES ==========\n")

    for item in missing_labels:
        print(item)
# Out:
# ========== FULL DATASET REPORT ==========
#
# Total Images: 893
# Total Annotations: 1748
#
# Class Distribution:
# Healthy (0): 897
# Unhealthy (1): 851
#
# Missing Labels: 7
# Empty Labels: 1
# Invalid Labels: 0
# Missing Images: 3
#
# ========== MISSING LABEL FILES ==========
#
# healthy_0018.jpg
# healthy_0038.jpg
# healthy_0057.jpg
# healthy_0059.jpg
# healthy_0343.jpg
# healthy_0157.jpg
# healthy_0108.jpg

# %%
import os
from collections import Counter, defaultdict

# =====================================
# DATASET PATHS
# =====================================

SPLITS = ["train", "val", "test"]

BASE_IMAGE_DIR = "../detection_dataset/images"
BASE_LABEL_DIR = "../detection_dataset/labels"

IMAGE_EXTENSIONS = (".jpg", ".jpeg", ".png")

# =====================================
# GLOBAL COUNTERS
# =====================================

missing_labels = defaultdict(list)
missing_images = defaultdict(list)
empty_labels = defaultdict(list)
invalid_labels = defaultdict(list)

class_counter = Counter()

split_image_count = Counter()
split_annotation_count = Counter()

total_images = 0
total_annotations = 0

# =====================================
# CHECK ALL SPLITS
# =====================================

for split in SPLITS:

    IMAGE_DIR = os.path.join(BASE_IMAGE_DIR, split)
    LABEL_DIR = os.path.join(BASE_LABEL_DIR, split)

    print(f"\n========== CHECKING {split.upper()} ==========")

    image_files = [
        f for f in os.listdir(IMAGE_DIR)
        if f.lower().endswith(IMAGE_EXTENSIONS)
    ]

    label_files = [
        f for f in os.listdir(LABEL_DIR)
        if f.endswith(".txt")
    ]

    split_image_count[split] = len(image_files)

    # ---------------------------------
    # IMAGE -> LABEL CHECK
    # ---------------------------------

    for image_file in image_files:

        total_images += 1

        image_name = os.path.splitext(image_file)[0]
        label_file = image_name + ".txt"

        label_path = os.path.join(LABEL_DIR, label_file)

        # Missing label
        if not os.path.exists(label_path):

            missing_labels[split].append(image_file)
            continue

        # Empty label
        if os.path.getsize(label_path) == 0:

            empty_labels[split].append(label_file)
            continue

        # Read label file
        with open(label_path, "r") as f:
            lines = f.readlines()

        split_annotation_count[split] += len(lines)
        total_annotations += len(lines)

        for line in lines:

            parts = line.strip().split()

            # Invalid YOLO format
            if len(parts) != 5:

                invalid_labels[split].append(label_file)
                continue

            class_id = parts[0]

            class_counter[class_id] += 1

    # ---------------------------------
    # LABEL -> IMAGE CHECK
    # ---------------------------------

    for label_file in label_files:

        label_name = os.path.splitext(label_file)[0]

        image_found = False

        for ext in IMAGE_EXTENSIONS:

            image_path = os.path.join(
                IMAGE_DIR,
                label_name + ext
            )

            if os.path.exists(image_path):

                image_found = True
                break

        if not image_found:

            missing_images[split].append(label_file)

# =====================================
# FINAL REPORT
# =====================================

print("\n\n========== FULL DATASET REPORT ==========")

print(f"\nTotal Images: {total_images}")
print(f"Total Annotations: {total_annotations}")

# -------------------------------------
# SPLIT DISTRIBUTION
# -------------------------------------

print("\n========== SPLIT DISTRIBUTION ==========")

for split in SPLITS:

    print(f"\n{split.upper()}")

    print(f"Images       : {split_image_count[split]}")
    print(f"Annotations  : {split_annotation_count[split]}")

# -------------------------------------
# CLASS DISTRIBUTION
# -------------------------------------

print("\n========== CLASS DISTRIBUTION ==========")

print(f"Healthy (0)   : {class_counter['0']}")
print(f"Unhealthy (1) : {class_counter['1']}")

# -------------------------------------
# LABELING STATUS
# -------------------------------------

print("\n========== LABELING STATUS ==========")

for split in SPLITS:

    total_missing = len(missing_labels[split])

    print(f"\n{split.upper()}")

    print(f"Need Labeling : {total_missing}")

    if total_missing > 0:

        print("\nMissing Label Files:")

        for item in missing_labels[split]:
            print(f"  - {item}")

# -------------------------------------
# OTHER ISSUES
# -------------------------------------

print("\n========== OTHER ISSUES ==========")

for split in SPLITS:

    print(f"\n{split.upper()}")

    print(f"Missing Images : {len(missing_images[split])}")
    print(f"Empty Labels   : {len(empty_labels[split])}")
    print(f"Invalid Labels : {len(invalid_labels[split])}")

# -------------------------------------
# EMPTY LABEL DETAILS
# -------------------------------------

for split in SPLITS:

    if empty_labels[split]:

        print(f"\n========== {split.upper()} EMPTY LABELS ==========\n")

        for item in empty_labels[split]:
            print(item)

# -------------------------------------
# INVALID LABEL DETAILS
# -------------------------------------

for split in SPLITS:

    if invalid_labels[split]:

        print(f"\n========== {split.upper()} INVALID LABELS ==========\n")

        for item in invalid_labels[split]:
            print(item)

# -------------------------------------
# MISSING IMAGE DETAILS
# -------------------------------------

for split in SPLITS:

    if missing_images[split]:

        print(f"\n========== {split.upper()} MISSING IMAGES ==========\n")

        for item in missing_images[split]:
            print(item)

print("\n========== DATASET CHECK COMPLETED ==========")
# Out:
# ========== CHECKING TRAIN ==========
#
# ========== CHECKING VAL ==========
#
# ========== CHECKING TEST ==========
#
#
# ========== FULL DATASET REPORT ==========
#
# Total Images: 2432
# Total Annotations: 2387
#
# ========== SPLIT DISTRIBUTION ==========
#
# TRAIN
# Images       : 1698
# Annotations  : 1230
#
# VAL
# Images       : 486
# Annotations  : 948
#
# TEST
# Images       : 248
# Annotations  : 209
#
# ========== CLASS DISTRIBUTION ==========
# Healthy (0)   : 1494
# Unhealthy (1) : 893
#
# ========== LABELING STATUS ==========
#
# TRAIN
# Need Labeling : 1076
#
# Missing Label Files:
#   - unhealthy_0943.jpg
#   - healthy_0465.jpg
#   - unhealthy_0544.jpg
#   - healthy_0845.jpg
#   - healthy_0579.jpg
#   - healthy_1344.jpg
#   - healthy_0521.jpg
#   - unhealthy_0492.jpg
#   - unhealthy_1018.jpg
#   - unhealthy_0678.jpg
#   - healthy_0952.jpg
#   - healthy_0677.jpg
#   - healthy_1369.jpg
#   - unhealthy_0664.jpg
#   - healthy_0459.jpg
#   - healthy_0863.jpg
#   - healthy_0549.jpg
#   - unhealthy_0969.jpg
#   - unhealthy_0852.jpg
#   - unhealthy_0452.jpg
#   - healthy_1035.jpg
#   - unhealthy_0900.jpg
#   - unhealthy_0515.jpg
#   - healthy_1013.jpg
#   - unhealthy_0839.jpg
#   - unhealthy_0599.jpg
#   - unhealthy_0461.jpg
#   - healthy_1089.jpg
#   - unhealthy_0673.jpg
#   - unhealthy_0931.jpg
#   - unhealthy_0543.jpg
#
# classes.txt
#
# ========== VAL MISSING IMAGES ==========
#
# classes.txt
#
# ========== TEST MISSING IMAGES ==========
#
# classes.txt
#
# ========== DATASET CHECK COMPLETED ==========

# %%
print("\n========== MISSING IMAGE FILES ==========\n")

if len(missing_images) == 0:
    print("No missing images found!")

else:
    for i, item in enumerate(missing_images, start=1):
        print(f"{i}. {item}")
# Out:
# ========== MISSING IMAGE FILES ==========
#
# 1. train
# 2. val
# 3. test

# %%
from ultralytics import YOLO
import pandas as pd
import matplotlib.pyplot as plt

# LOAD MODEL
model = YOLO(
    "../runs/detect/models/trained/bitol_yolov8/weights/best.pt"
)

print("Model loaded successfully!")

# TEST EVALUATION
metrics = model.val(
    data="../detection_dataset/data.yaml",
    split="test"
)

print("Test evaluation completed!")

# OVERALL RESULTS
map50 = metrics.box.map50
map5095 = metrics.box.map
precision = metrics.box.mp
recall = metrics.box.mr

results_df = pd.DataFrame({
    "Metric": [
        "Precision",
        "Recall",
        "mAP50",
        "mAP50-95"
    ],
    "Score": [
        precision,
        recall,
        map50,
        map5095
    ]
})

display(results_df)

# CLASS-WISE RESULTS
class_names = ["healthy", "unhealthy"]

class_df = pd.DataFrame({
    "Class": class_names,
    "Precision": metrics.box.p,
    "Recall": metrics.box.r,
    "mAP50": metrics.box.ap50,
    "mAP50-95": metrics.box.ap
})

display(class_df)

# PLOT
plt.figure(figsize=(8,5))
plt.bar(results_df["Metric"], results_df["Score"])
plt.ylim(0,1)
plt.title("Overall Test Performance")
plt.show()

# PREDICTION
results = model.predict(
    source="../detection_dataset/images/test",
    save=True,
    conf=0.5
)

print("Prediction completed!")
# Out:
# Model loaded successfully!
# Ultralytics 8.4.51  Python-3.14.5 torch-2.12.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1266.9442.7 MB/s, size: 400.1 KB)
# val: Scanning W:\CODE\Bitol_Computer_Vision_System\detection_dataset\labels\test.cache... 51 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 51/51 8.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.8s/it 11.2s5.1ss
#                    all         51        110      0.746      0.746      0.746      0.408
#                healthy         14         43      0.553      0.836      0.646      0.304
#              unhealthy         37         67      0.939      0.657      0.847      0.512
# Speed: 3.7ms preprocess, 193.4ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to W:\CODE\Bitol_Computer_Vision_System\notebooks\runs\detect\val
# Test evaluation completed!
#       Metric     Score
# 0  Precision  0.745939
# 1     Recall  0.746139
# 2      mAP50  0.746294
# 3   mAP50-95  0.408367
#        Class  Precision    Recall     mAP50  mAP50-95
# 0    healthy   0.553352  0.835562  0.645898  0.304282
# 1  unhealthy   0.938526  0.656716  0.846691  0.512452
# image 1/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0125.jpg: 1024x1024 1 healthy, 212.8ms
# image 2/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0126.jpg: 1024x1024 3 healthys, 190.4ms
# image 3/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0127.jpg: 1024x1024 2 healthys, 183.1ms
# image 4/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0128.jpg: 1024x1024 2 healthys, 182.8ms
# image 5/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0129.jpg: 1024x1024 1 healthy, 183.5ms
# image 6/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0130.jpg: 1024x1024 1 healthy, 187.5ms
# image 7/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0131.jpg: 1024x1024 4 healthys, 181.3ms
# image 8/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_0132.jpg: 1024x1024 1 healthy, 197.0ms
# image 9/51 w:\CODE\Bitol_Computer_Vision_System\notebooks\..\detection_dataset\images\test\healthy_
7ms inference, 1.3ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to W:\CODE\Bitol_Computer_Vision_System\notebooks\runs\detect\predict
# Prediction completed!

# %%
from ultralytics import YOLO
import pandas as pd
import matplotlib.pyplot as plt

# ==========================================
# LOAD MODEL
# ==========================================

model = YOLO(
    "../runs/detect/models/trained/bitol_yolov8/weights/best.pt"
)

print("Model loaded successfully!")

# ==========================================
# TEST EVALUATION
# ==========================================

metrics = model.val(
    data="../detection_dataset/data.yaml",
    split="test"
)

print("Test evaluation completed!")

# ==========================================
# OVERALL METRICS
# ==========================================

map50 = metrics.box.map50
map5095 = metrics.box.map
precision = metrics.box.mp
recall = metrics.box.mr

# F1 Score
f1_score = (2 * precision * recall) / (precision + recall)

results_df = pd.DataFrame({
    "Metric": [
        "Precision",
        "Recall",
        "F1-Score",
        "mAP50",
        "mAP50-95"
    ],
    "Score": [
        precision,
        recall,
        f1_score,
        map50,
        map5095
    ]
})

print("\n========== OVERALL TEST RESULTS ==========\n")

display(results_df)

# ==========================================
# CLASS-WISE RESULTS
# ==========================================

class_names = ["healthy", "unhealthy"]

class_precision = metrics.box.p
class_recall = metrics.box.r

# CLASS-WISE F1
class_f1 = (
    2 * class_precision * class_recall
) / (
    class_precision + class_recall
)

class_df = pd.DataFrame({
    "Class": class_names,
    "Precision": class_precision,
    "Recall": class_recall,
    "F1-Score": class_f1,
    "mAP50": metrics.box.ap50,
    "mAP50-95": metrics.box.ap
})

print("\n========== CLASS-WISE RESULTS ==========\n")

display(class_df)

# ==========================================
# OVERALL METRIC PLOT
# ==========================================

plt.figure(figsize=(10,5))

plt.bar(
    results_df["Metric"],
    results_df["Score"]
)

plt.ylim(0,1)

plt.title("Overall Test Performance")

plt.ylabel("Score")

plt.show()

# ==========================================
# CLASS-WISE MAP50 PLOT
# ==========================================

plt.figure(figsize=(6,5))

plt.bar(
    class_df["Class"],
    class_df["mAP50"]
)

plt.ylim(0,1)

plt.title("Healthy vs Unhealthy mAP50")

plt.ylabel("mAP50")

plt.show()

# ==========================================
# CLASS-WISE F1 PLOT
# ==========================================

plt.figure(figsize=(6,5))

plt.bar(
    class_df["Class"],
    class_df["F1-Score"]
)

plt.ylim(0,1)

plt.title("Healthy vs Unhealthy F1-Score")

plt.ylabel("F1-Score")

plt.show()

# ==========================================
# PREDICTION
# ==========================================

results = model.predict(
    source="../detection_dataset/images/test",
    save=True,
    conf=0.5
)

print("\nPrediction completed!")

print("\nPrediction images saved inside:")

print("runs/detect/predict")
# Out:
# Model loaded successfully!
# Ultralytics 8.4.103 🚀 Python-3.14.4 torch-2.13.0+cu130 CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 442.9±175.7 MB/s, size: 312.2 KB)
# val: Scanning /home/mehedinaeem/Desktop/Code/Bitol_Computer_Vision_System/detection_dataset/labels/test... 92 images, 156 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 248/248 3.6Kit/s 0.1s
# val: New cache created: /home/mehedinaeem/Desktop/Code/Bitol_Computer_Vision_System/detection_dataset/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 25% ━━━───────── 4/16 7.6s/it 19.9s<1:32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 19
#      15 # ==========================================
#      16 # TEST EVALUATION
#      17 # ==========================================
#      18
# ---> 19 metrics = model.val(
#      20     data="../detection_dataset/data.yaml",
#      21     split="test"
#      22 )
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/engine/model.py:620, in Model.val(self, validator, **kwargs)
#     617 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     619 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 620 validator(model=self.model)
#     621 self.metrics = validator.metrics
#     622 return validator.metrics
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/engine/validator.py:243, in BaseValidator.__call__(self, trainer, model)
#     240 with autocast(self.training and self.args.quantize == 16, device=self.device.type):
#     241     # Inference
#     242     with dt[1]:
# --> 243         preds = model(batch["img"], augment=augment)
#     245     # Loss
#     246     with dt[2]:
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/nn/autobackend.py:281, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     278 if self.format == "pt":
#     279     forward_kwargs = {"augment": augment, "visualize": visualize, "embed": embed, **kwargs}
# --> 281 y = self.backend.forward(im, **forward_kwargs)
#     283 if isinstance(y, (list, tuple)):
#     284     if len(self.names) == 999 and (self.task == "segment" or len(y) == 2):  # segments and names not defined
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/nn/backends/pytorch.py:90, in PyTorchBackend.forward(self, im, augment, visualize, embed, **kwargs)
#      75 def forward(
#      76     self, im: torch.Tensor, augment: bool = False, visualize: bool = False, embed: list | None = None, **kwargs: Any
#      77 ) -> torch.Tensor | list[torch.Tensor]:
#      78     """Run native PyTorch inference with support for augmentation, visualization, and embeddings.
#      79
#      80     Args:
#    (...)     88         (torch.Tensor | list[torch.Tensor]): Model predictions as tensor(s).
#      89     """
# ---> 90     return self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/nn/tasks.py:154, in BaseModel.forward(self, x, *args, **kwargs)
#     152 if isinstance(x, dict):  # for cases of training and validating while training.
#     153     return self.loss(x, *args, **kwargs)
# --> 154 return self.predict(x, *args, **kwargs)
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/nn/tasks.py:171, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     169 if augment:
#     170     return self._predict_augment(x)
# --> 171 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/nn/tasks.py:193, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     191 if profile:
#     192     self._profile_one_layer(m, x, dt)
# --> 193 x = m(x)  # run
#     194 y.append(x if m.i in self.save else None)  # save output
#     195 if visualize:
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/nn/modules/head.py:161, in Detect.forward(self, x)
#     157 def forward(
#     158     self, x: list[torch.Tensor]
#     159 ) -> dict[str, torch.Tensor] | torch.Tensor | tuple[torch.Tensor, dict[str, torch.Tensor]]:
#     160     """Concatenates and returns predicted bounding boxes and class probabilities."""
# --> 161     preds = self.forward_head(x, **self.one2many)
#     162     if self.end2end:
#     163         x_detach = [xi.detach() for xi in x]
#
# File ~/Desktop/Code/Bitol_Computer_Vision_System/.venv-1/lib/python3.14/site-packages/ultralytics/nn/modules/head.py:153, in Detect.forward_head(self, x, box_head, cls_head)
#     151     return dict()
#     152 bs = x[0].shape[0]  # batch size
# --> 153 boxes = torch.cat([box_head[i](x[i]).view(bs, 4 * self.reg_max, -1) for i in range(self.nl)], dim=-1)
#     154 scores = torch.cat([cls_head[i](x[i]).view(bs, self.nc, -1) for i in range(self.nl)], dim=-1)
#     155 return dict(boxes=boxes, scores=scores, feats=x)
#
# KeyboardInterrupt:
